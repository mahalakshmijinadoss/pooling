# %% [markdown]
# <a href="https://colab.research.google.com/github/mahalakshmijinadoss/pooling/blob/main/engtrac1_fin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from torch.nn.functional import softmax

# %%
# !pip install transformers[sentencepiece]==4.10.0 datasets --quiet
# Out:
#      |████████████████████████████████| 2.8 MB 31.1 MB/s
#      |████████████████████████████████| 311 kB 55.4 MB/s
#      |████████████████████████████████| 67 kB 5.5 MB/s
#      |████████████████████████████████| 895 kB 53.5 MB/s
#      |████████████████████████████████| 3.3 MB 48.1 MB/s
#      |████████████████████████████████| 596 kB 52.0 MB/s
#      |████████████████████████████████| 1.1 MB 41.7 MB/s
#      |████████████████████████████████| 1.1 MB 50.7 MB/s
#      |████████████████████████████████| 243 kB 68.8 MB/s
#      |████████████████████████████████| 133 kB 62.0 MB/s
#      |████████████████████████████████| 271 kB 67.8 MB/s
#      |████████████████████████████████| 94 kB 3.6 MB/s
#      |████████████████████████████████| 144 kB 33.4 MB/s

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
# Out:
# Downloading:   0%|          | 0.00/354 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/797 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("Hate-speech-CNERG/bert-base-uncased-hatexplain-rationale-two")
model = Model_Rational_Label.from_pretrained("Hate-speech-CNERG/bert-base-uncased-hatexplain-rationale-two")

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)

# %%
from tqdm.notebook import tqdm, trange

# %%
tweet_df = pd.read_csv("/content/drive/MyDrive/total_data_twitter.csv", lineterminator='\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (11,17,24,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
subset_df = tweet_df[tweet_df['language'].isin(['hi','en','ta'])]
hin_df = subset_df[subset_df['language'] == 'en']

# %%
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# %%
hin_df.shape
# Out:
# (815998, 43)

# %%
tweets=hin_df["tweet"].tolist()

# %%
seq_len = [len(i.split()) for i in tweets]

pd.Series(seq_len).hist(bins = 5)

# %%
hin_df['len']=seq_len
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
c=hin_df[hin_df['len']>70]
c.shape
# Out:
# (136, 44)

# %%
import torch

# %%
device = torch.device('cuda')
model.eval()
_ = model.to(device)

# %%
label_map= {
        0: 'None', 
        1: 'Hate'
    }

# %%
torch.cuda.empty_cache()

# %%
offense_list = []
offense_confidence = []
bs = 16
for x in trange(len(hin_df['tweet'])//bs+1):
    batch_x = list(hin_df['tweet'][x*bs:x*bs+bs])
    clean_x = [preprocess(tweet) for tweet in batch_x]
    encoded_input = tokenizer(clean_x, return_tensors='pt', padding=True, truncation=True, max_length=70)
    encoded_input.to(device)
    output = model(**encoded_input)
    out = softmax(output[0].data, dim=-1).detach().cpu()
    labels = [label_map[i] for i in torch.argmax(out,-1).numpy()]
    offense_list.extend(labels)
    for x_ind, y_ind in enumerate(torch.argmax(out,-1)):
        offense_confidence.append(round(out[x_ind, y_ind].item(),2))
    if(x%1000 == 0):
        print('GPU memory: %.1f' % (torch.cuda.memory_allocated() // 1024 ** 2))
# Out:
#   0%|          | 0/51000 [00:00<?, ?it/s]
# GPU memory: 1219.0
# GPU memory: 1933.0
# GPU memory: 1956.0
# GPU memory: 1263.0
# GPU memory: 1199.0
# GPU memory: 1708.0
# GPU memory: 1290.0
# GPU memory: 1806.0
# GPU memory: 1956.0
# GPU memory: 1968.0
# GPU memory: 1964.0
# GPU memory: 1903.0
# GPU memory: 1216.0
# GPU memory: 1595.0
# GPU memory: 1231.0
# GPU memory: 1903.0
# GPU memory: 1615.0
# GPU memory: 1777.0
# GPU memory: 1303.0
# GPU memory: 1976.0
# GPU memory: 1730.0
# GPU memory: 1460.0
# GPU memory: 1911.0
# GPU memory: 1216.0
# GPU memory: 1879.0
# GPU memory: 1953.0
# GPU memory: 1128.0
# GPU memory: 1366.0
# GPU memory: 1915.0
# GPU memory: 1228.0
# GPU memory: 1957.0
# GPU memory: 1984.0
# GPU memory: 1718.0
# GPU memory: 938.0
# GPU memory: 1946.0
# GPU memory: 1680.0
# GPU memory: 1900.0
# GPU memory: 1810.0
# GPU memory: 1231.0
# GPU memory: 1746.0
# GPU memory: 1738.0
# GPU memory: 1902.0
# GPU memory: 1981.0
# GPU memory: 1615.0
# GPU memory: 1830.0
# GPU memory: 1232.0
# GPU memory: 1231.0
# GPU memory: 1907.0
# GPU memory: 1230.0
# GPU memory: 1041.0
# GPU memory: 1898.0

# %%
hin_df['eng_trac1_confidence']=offense_confidence
hin_df['eng_trac1_label']=offense_list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hin_df
# Out:
#          Unnamed: 0  ... eng_trac1_label
# 0                 0  ...            Hate
# 1                 1  ...            Hate
# 2                 2  ...            Hate
# 3                 3  ...            None
# 4                 4  ...            Hate
# ...             ...  ...             ...
# 1560053      560053  ...            Hate
# 1560056      560056  ...            None
# 1560256      560256  ...            None
# 1560496      560496  ...            None
# 1560527      560527  ...            None
#
# [815998 rows x 46 columns]

# %%
hin_df.to_csv('eng_trac1_final.csv')
